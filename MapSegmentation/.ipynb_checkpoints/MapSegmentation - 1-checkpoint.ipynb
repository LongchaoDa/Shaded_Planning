# %%
import cv2;
import matplotlib.pyplot as plt
import requests
import os.path
from main import *

# %%
# Tempe corner coordinates
# latTop = 33.4365
# latBottom = 33.32759
# longLeft = -111.9784
# longRight = -111.89361

# dirName = "DataSetTempe"
# areaName = "Tempe City"

latTop = 33.42548
latBottom = 33.42200
longLeft = -111.94126
longRight = -111.93666

dirName = "DataSetByeng"
areaName = "Brickyard Engineering locality"

zoom = 20
imgSize = 400
segmentMap(latTop, latBottom, longLeft, longRight, zoom, imgSize, dirName, areaName)
# Out:
# https://maps.googleapis.com/maps/api/staticmap?center=33.42548,-111.94126&zoom=20&size=400x400&maptype=satellite&key=AIzaSyBYPwYOvF-GhIF8jBFJ06adOp_2z4wlhyM
# DataSetByeng/img1-1.png
# https://maps.googleapis.com/maps/api/staticmap?center=33.42548,-111.94072355819702&zoom=20&size=400x400&maptype=satellite&key=AIzaSyBYPwYOvF-GhIF8jBFJ06adOp_2z4wlhyM
# DataSetByeng/img1-2.png
# https://maps.googleapis.com/maps/api/staticmap?center=33.42548,-111.94018711639404&zoom=20&size=400x400&maptype=satellite&key=AIzaSyBYPwYOvF-GhIF8jBFJ06adOp_2z4wlhyM
# DataSetByeng/img1-3.png
# https://maps.googleapis.com/maps/api/staticmap?center=33.42548,-111.93965067459106&zoom=20&size=400x400&maptype=satellite&key=AIzaSyBYPwYOvF-GhIF8jBFJ06adOp_2z4wlhyM
# DataSetByeng/img1-4.png
# https://maps.googleapis.com/maps/api/staticmap?center=33.42548,-111.93911423278809&zoom=20&size=400x400&maptype=satellite&key=AIzaSyBYPwYOvF-GhIF8jBFJ06adOp_2z4wlhyM
# DataSetByeng/img1-5.png
# ...

# %%
dirName = 'DataSetByeng'

filePath = os.path.join(dirName, "img1-1.png")
combinedImage = cv2.imread(filePath)
plt.imshow(combinedImage)
combinedImage = cv2.cvtColor(combinedImage, cv2.COLOR_BGR2RGB)

# %%
combinedImage.shape
# Out:
# (400, 400, 3)

# %%
combinedImage = [];
i = 1
j = 1
while(1):
    j = 1
    horizontalImage = [];
    while(1):
        filePath = os.path.join(dirName, f"img{i}-{j}.png")
        # checking if it is a file
        if os.path.isfile(filePath):
            image = cv2.imread(filePath)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            if(horizontalImage == []):
                horizontalImage = image;
            else:
                horizontalImage = cv2.hconcat([horizontalImage, image]);
        else: 
            break;
        j+=1
    if j == 1:
        break;
    if combinedImage == []:
        combinedImage = horizontalImage;
    else:
        combinedImage = cv2.vconcat([combinedImage, horizontalImage]);
    i+=1;
plt.imshow(combinedImage)
# Out:
# /var/folders/sp/p58zvn2x0j74k4wxmrwnyh7h0000gn/T/ipykernel_72359/3840303949.py:13: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if(horizontalImage == []):
# /var/folders/sp/p58zvn2x0j74k4wxmrwnyh7h0000gn/T/ipykernel_72359/3840303949.py:22: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if combinedImage == []:

# %%
combineSegmentedMap(dirName)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 combineSegmentedMap(dirName)
#
# File ~/Desktop/ShadyProject/Shaded_planning/MapSegmentation/main.py:97, in combineSegmentedMap(dirName)
#      95 # checking if it is a file
#      96 if os.path.isfile(filePath):
# ---> 97     image = cv2.imread(filePath)
#      98     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#      99     if(horizontalImage == []):
#
# NameError: name 'cv2' is not defined
