# %%
import imp
tm = imp.load_source('totalShadeMask.py', '../Utils/totalShadeMask.py')
# Out:
# <a target="_blank" href="https://colab.research.google.com/github/facebookresearch/segment-anything/blob/main/notebooks/automatic_mask_generator_example.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
mp = imp.load_source('MercatorProjection.py', '../MapSegmentation/MercatorProjection.py')
intersect = imp.load_source('checkIntersection.py', '../Utils/checkIntersection.py')
import osm2gmns as og
import pandas as pd
import numpy as np
import os as os
import cv2;
import matplotlib.pyplot as plt
import requests
import json
from collections import OrderedDict
import math
import copy

# %% [markdown]
# ## Getting the OSM file

# %%
# For now, not using this
# og.downloadOSMData(3444656, 'map.osm')

input_file = 'map (1).osm'
net = og.getNetFromFile(input_file, network_types=('walk'))
# Use og.show(net) to visualize the network model
# og.show(net)
# Out:
# arguments used for network parsing:
#   filename: map (1).osm
#   network_types: walk
#   link_types: all
#   POI: False
#   POI_sampling_ratio: 1.0
#   strict_mode: True
#   offset: no
#   min_nodes: 1
#   combine: False
#   bbox: None
#   default_lanes: False
#   default_speed: False
#   default_capacity: False
#   start_node_id: 0
#   start_link_id: 0
#
# Building Network from OSM file
#   reading osm file
#   parsing osm network
#     generating nodes and links
#   number of nodes: 420, number of links: 782, number of pois: 0

# %%
og.outputNetToCSV(net) #net

# %% [markdown]
# ## Getting the image

# %%
dirPath = os.path.join('..', 'MapSegmentation', 'DataSetByeng');
imgIndex = '7-7';
imgPath = 'img' + imgIndex + '.png';
imgPath = os.path.join(dirPath, imgPath);
combinedImage = cv2.imread(imgPath);
combinedImage = cv2.cvtColor(combinedImage, cv2.COLOR_BGR2RGB)
plt.imshow(combinedImage)

# %% [markdown]
# ## Getting image data - centre and edge coordinates.

# %%
# Getting centre coordinates of this image through image directory:-
imgDirPath = os.path.join(dirPath, "imageDirectory");
f = open(imgDirPath);
imgData = json.load(f)

imgCoords = imgData['imageIndex'][f"{7}_{7}"];

# %%
imgCoords
# Out:
# {'lat': 33.42279370098351, 'long': -111.93804134918213}

# %%
# Preparing to get the corner coordinates for that image:-
areaCoords = imgData["coordinates"];
latTop = areaCoords['latTop'];
longLeft = areaCoords['longLeft'];
imgSize = imgData["imageSize"];
zoom = imgData["zoom"];
[SWlat, SWlng, NElat, NElng] = mp.getImageBounds(imgSize, zoom, latTop, longLeft)

# %%
# Factors with which to increase lat and long for each image
latFactor = latTop - SWlat
longFactor = longLeft - SWlng
print(latFactor, longFactor)
# Out:
# 0.0002238582513740539 0.0002682209014892578

# %%
# Getting the corners for an image
imgLatTop = imgCoords["lat"] + latFactor/2;
imgLatBot = imgCoords["lat"] - latFactor/2;
imgLongLeft = imgCoords["long"] - longFactor/2;
imgLongRight = imgCoords["long"] + longFactor/2;
print(imgLatTop)
print(imgLatBot)
print(imgLongLeft)
print(imgLongRight)
# Out:
# 33.42245791360645
# 33.42223405535508
# -111.93710257602692
# -111.93683435512543

# %% [markdown]
# ## Converting all Linestrings in Links array to list of actual coordinates.

# %%
link_dataframe = pd.read_csv("link.csv")

# %%
links = link_dataframe.to_numpy()

# %%
for link in links:
    coords = link[12][12:-1].split(',');
    for i in range(len(coords)):
        coords[i] = coords[i].split();
        coords[i] = [float(coords[i][1]), float(coords[i][0])];
        link[12] = coords

# %%
links[0]
# Out:
# array(['West 6th Street', 0, 5591085, 0, 1, 1, 18.04, 1.0, 40.0, nan,
#        'residential', 6,
#        list([[33.4243385, -111.9412691], [33.4243393, -111.941075]]),
#        'walk', 1, 0, nan, nan], dtype=object)

# %% [markdown]
# ### Here, we traverse over roads in link.csv. Using the end points of the link, we then find the coordinates of the end points using node.csv. Then, we find an equation of the line connecting those two coordinates. And if points on that line pass through our image, implies the path passes through our image.

# %%
link_dataframe = pd.read_csv("link.csv")
node_dataframe = pd.read_csv("node.csv")

# %%
links = link_dataframe.to_numpy();
nodes = node_dataframe.to_numpy();

# %%
# Creating a dictionary of nodes and their coordinates
nodeCoordDict = {}
for node in nodes:
    nodeNum = node[1];
    nodeXCoord = node[10];
    nodeYCoord= node[9];
    nodeCoordDict[nodeNum] = [nodeXCoord, nodeYCoord];

# %% [markdown]
# ### In each image, we check what all link IDs are present. Then, we check their corresponding path names.

# %%
# Creating a dictionary of end nodes, and the path.
endNodesOfPath = {};
for link in links:
    nodeTuple = (link[3], link[4]);
    nodeTuple = tuple(sorted(nodeTuple))
    pathName = link[0];
    endNodesOfPath[nodeTuple] = pathName;

# %%
# Creating a dictionary of end nodes, and the linkID.
endNodesOfLinkID = {};
for link in links:
    nodeTuple = (link[3], link[4]);
    nodeTuple = tuple(sorted(nodeTuple))
    linkID = link[1];
    endNodesOfLinkID[nodeTuple] = linkID;

# %%
# Creating a dictionary of linkID, and the nodePair.
linkIDToNodePair = {};
for link in links:
    nodeTuple = (link[3], link[4]);
    nodeTuple = tuple(sorted(nodeTuple))
    linkID = link[1];
    linkIDToNodePair[linkID] = nodeTuple;

# %%
# Creating a dictionary of linkIDs and path names.
linkIDAndPath = {};
for link in links:
    linkID = link[1];
    pathName = link[0];
    linkIDAndPath[linkID] = pathName;

# %% [markdown]
# ## Finding what roads are present in each image

# %%
# Getting centre coordinates of this image through image directory:-
imgDirPath = os.path.join(dirPath, "imageDirectory");
f = open(imgDirPath);
imgData = json.load(f)

imageLinksDir = {};
for i in range(2, 9):
    for j in range(2, 10):
        imgCoords = imgData['imageIndex'][f"{i}_{j}"];
        # Getting the corners for an image
        imgLatTop = imgCoords["lat"] + latFactor/2;
        imgLatBot = imgCoords["lat"] - latFactor/2;
        imgLongLeft = imgCoords["long"] - longFactor/2;
        imgLongRight = imgCoords["long"] + longFactor/2;
        
        linksInImage = {};
        
        for linkID in linkIDToNodePair:

            nodePair = linkIDToNodePair[linkID]
            
            node0 = nodePair[0];
            node1 = nodePair[1];

            node0_Coord = nodeCoordDict[node0];
            node1_Coord = nodeCoordDict[node1];
            
            (node0_x, node0_y) = mp.latLngToPoint(node0_Coord[0], node0_Coord[1]);
        
            (node1_x, node1_y) = mp.latLngToPoint(node1_Coord[0], node1_Coord[1]);

            node0Point = intersect.Point(node0_x, node0_y);
            node1Point = intersect.Point(node1_x, node1_y);

            # Image corners
            (imgLatTop_, imgLongLeft_) = mp.latLngToPoint(imgLatTop, imgLongLeft);
            (imgLatBot_, imgLongRight_) = mp.latLngToPoint(imgLatBot, imgLongRight);

            pointNW = intersect.Point(imgLatTop_, imgLongLeft_);
            pointNE = intersect.Point(imgLatTop_, imgLongRight_);
            pointSW = intersect.Point(imgLatBot_, imgLongLeft_);
            pointSE = intersect.Point(imgLatBot_, imgLongRight_);


            # Checking intersection with left edge of the image
            if intersect.doIntersect(node0Point, node1Point, pointNW, pointSW):
                linksInImage[linkID] = 1;
            # Checking intersection with top edge of the image
            elif intersect.doIntersect(node0Point, node1Point, pointNW, pointNE): 
                linksInImage[linkID] = 1;
            # Checking intersection with right edge of the image
            elif intersect.doIntersect(node0Point, node1Point, pointNE, pointSE): 
                linksInImage[linkID] = 1;
                # Checking intersection with bottom edge of the image
            elif intersect.doIntersect(node0Point, node1Point, pointSW, pointSE):
                linksInImage[linkID] = 1;
                
            
#         print(i, j, linksInImage);
        a = (i, j);
        imageLinksDir[a] = linksInImage;
imageLinksDir
# Out:
# {(2, 2): {479: 1, 480: 1},
#  (2, 3): {170: 1, 556: 1},
#  (2, 4): {281: 1},
#  (2, 5): {115: 1, 281: 1, 282: 1, 295: 1, 296: 1, 297: 1, 298: 1, 635: 1},
#  (2, 6): {},
#  (2, 7): {107: 1},
#  (2, 8): {},
#  (2, 9): {},
#  (3, 2): {505: 1, 506: 1, 558: 1},
#  (3, 3): {151: 1, 170: 1, 556: 1},
#  (3, 4): {329: 1},
#  (3, 5): {114: 1, 115: 1, 272: 1, 329: 1},
#  (3, 6): {268: 1, 269: 1, 274: 1},
#  (3, 7): {108: 1, 109: 1, 548: 1},
#  (3, 8): {361: 1},
#  (3, 9): {736: 1},
#  (4, 2): {618: 1, 650: 1},
#  (4, 3): {167: 1, 601: 1, 602: 1, 618: 1, 651: 1},
#  (4, 4): {},
#  (4, 5): {284: 1, 285: 1, 515: 1, 516: 1, 517: 1, 518: 1},
#  (4, 6): {285: 1, 286: 1, 291: 1},
#  (4, 7): {288: 1, 337: 1, 690: 1, 743: 1, 744: 1},
#  (4, 8): {337: 1, 338: 1, 495: 1, 496: 1, 740: 1, 741: 1},
#  (4, 9): {339: 1},
#  (5, 2): {},
#  (5, 3): {167: 1, 602: 1, 603: 1, 653: 1},
#  (5, 4): {},
#  (5, 5): {323: 1, 326: 1, 327: 1, 328: 1, 745: 1},
#  (5, 6): {320: 1, 321: 1, 745: 1, 746: 1, 747: 1},
#  (5, 7): {443: 1,
#   444: 1,
#   457: 1,
#   458: 1,
#   689: 1,
#   690: 1,
#   743: 1,
#   744: 1,
#   748: 1,
#   749: 1},
#  (5, 8): {445: 1, 446: 1, 447: 1, 448: 1, 740: 1, 741: 1},
#  (5, 9): {449: 1, 450: 1, 451: 1, 452: 1, 455: 1, 456: 1},
#  (6, 2): {201: 1, 202: 1},
#  (6, 3): {157: 1,
#   158: 1,
#   201: 1,
#   202: 1,
#   541: 1,
#   542: 1,
#   572: 1,
#   593: 1,
#   598: 1,
#   603: 1},
#  (6, 4): {50: 1, 51: 1, 706: 1},
#  (6, 5): {52: 1, 53: 1, 56: 1, 57: 1, 323: 1, 705: 1, 706: 1, 764: 1, 765: 1},
#  (6, 6): {56: 1,
#   57: 1,
#   60: 1,
#   61: 1,
#   320: 1,
#   321: 1,
#   704: 1,
#   705: 1,
#   762: 1,
#   763: 1},
#  (6, 7): {60: 1,
#   61: 1,
#   64: 1,
#   65: 1,
#   211: 1,
#   212: 1,
#   248: 1,
#   249: 1,
#   386: 1,
#   689: 1,
#   708: 1,
#   730: 1},
#  (6, 8): {64: 1, 65: 1, 730: 1},
#  (6, 9): {64: 1, 65: 1, 66: 1, 67: 1, 499: 1, 500: 1, 728: 1, 729: 1},
#  (7, 2): {639: 1},
#  (7, 3): {157: 1, 572: 1},
#  (7, 4): {},
#  (7, 5): {},
#  (7, 6): {},
#  (7, 7): {213: 1, 214: 1, 385: 1},
#  (7, 8): {},
#  (7, 9): {},
#  (8, 2): {},
#  (8, 3): {171: 1, 572: 1},
#  (8, 4): {481: 1, 482: 1},
#  (8, 5): {437: 1, 438: 1},
#  (8, 6): {},
#  (8, 7): {215: 1, 216: 1, 709: 1},
#  (8, 8): {},
#  (8, 9): {}}

# %% [markdown]
# ## Finding total shade mask

# %%
threshold = 70;
totalMask2 = tm.calculateTotalMask(imgPath, threshold)
# Out:
# 203.4853044086774
# 125.39883616830797
# 213.91847265221878
# 47.26116584797978
# 87.93011750154608
# 116.7414822620302
# 228.32474642894746
# 234.34117944824095
# 62.8606502986065
# 143.29633344477878
# 159.01559575795383
# 166.74560327198364
# 213.4568093385214
# 195.50573979591837
# 152.31460674157304
# 170.44907407407408
# 62.85946705945367
# 107.34010695187166
# 95.83538531691747
# 123.81431005110733
# 168.1727272727273
# 127.27835375431982
# 111.36792452830188
# 96.71915393654524
# 190.25290769611482
# 148.1547619047619
# 19.060263653483993
# 201.03280839895012
# 200.14012654012654
# 115.37878787878788
# 112.16329284750337
# 141.7991967871486
# 107.62162162162163
# 195.95685005393744
# 66.15484922575388
# 134.2233676975945
# 88.71612903225807
# 97.4659090909091
# 52.433471933471935
# 111.34860883797054
# 175.5194805194805
# 79.76543209876543
# 111.57449344457687
# 113.27039627039628
# 38.86666666666667
# 74.89193083573487
# 161.98997493734336
# 52.42835931700074
# 145.13574660633483
# 150.6171003717472
# 166.84754521963825
# 64.06222222222222
# 106.375
# 186.9765625
# 90.15494071146244
# 189.71606049693915
# 162.8395061728395
# 108.98333333333333
# 170.58035714285714
# 39.58181818181818
# 162.32326621923937
# 61.12264150943396
# 111.83054003724395
# 157.40588235294118
# 47.844783715012724
# 189.93259232699893
# 88.24780316344464
# 125.43418013856812
# 187.71706010380043
# 96.560327198364
# 182.3793103448276
# 77.80952380952381
# 96.60141093474427
# 100.78787878787878
# 104.63131813676908
# 78.53072625698324
# 68.21899224806202
# 123.81395348837209
# 80.47916666666667
# 63.13257575757576
# 70.96
# 167.16883116883116
# 69.33093525179856
# 92.15025906735751
# 179.63230240549828
# 183.0
# 93.72056921086676
# 166.03648915187378
# 119.81699346405229
# 132.70498084291188
# 98.0909090909091
# 98.22826823210657
# 216.1969696969697
# 188.37065637065638
# 140.36190476190475

# %% [markdown]
# ## Finding how much of a road is covered under shade in an image

# %%
imgCoords = imgData['imageIndex'][f"{7}_{7}"];
# Getting the corners for an image
imgLatTop = imgCoords["lat"] + latFactor/2;
imgLatBot = imgCoords["lat"] - latFactor/2;
imgLongLeft = imgCoords["long"] - longFactor/2;
imgLongRight = imgCoords["long"] + longFactor/2;

# %%
# Converting image corners to Mercator Projection
(xl, yt) = mp.latLngToPoint(imgLatTop, imgLongLeft);
(xr, yb) = mp.latLngToPoint(imgLatBot, imgLongRight);

# %%
(xl, xr)
# Out:
# (48.39951967314996, 48.39971040801324)

# %%
# Sampling over the edges of the image, to kind of map the 400 pixels to coordinates
yRange = np.linspace(yt, yb, 400);
xRange = np.linspace(xl, xr, 400);

# %%
# Converting end-point coordinates of the road to Mercator projection
imageLinks = [214]
nodePair0 = linkIDToNodePair[214]
path0_node0 = nodeCoordDict[nodePair0[0]];
path0_node1 = nodeCoordDict[nodePair0[1]];
(x0, y0) = mp.latLngToPoint(path0_node0[0], path0_node0[1]);
(x1, y1) = mp.latLngToPoint(path0_node1[0], path0_node1[1]);

# %%
totalMask3 = copy.deepcopy(totalMask2)

# %%
# All points below are Mercator's Projection.
totalPixelCount = 0;
shadedPixelCount = 0;
for y in yRange:
    leftPoint = (xl, y);
    rightPoint = (xr, y);
    
    # Line parellel to top/bottom edge of the image.
    line1 = (leftPoint, rightPoint);
    
    # Line joining the endpoints of the pathway.
    # top and bottom no relevance to actual position.
    topPoint = (x0, y0);
    bottomPoint = (x1, y1);
    line2 = (topPoint, bottomPoint);
    
    # Calculating intersection point of the 2 lines.
    (xIntersect, yIntersect) = intersect.line_intersection(line1, line2);
    
    # yIntersect should directly correspond to a pixel, as we mapped yRange to 400 pixels.
    # But it might not, as we our finding intersection using equation of line.
    for i in range(1, len(yRange) - 1):
        if(yRange[i-1] < yIntersect  and yRange[i + 1] > yIntersect) :
            yIntersect = yRange[i];
            break;
    # For xIntersect, we check between which two points in xRange does the xIntersect lies,
    # The point in between those 2 points will be our xIntersect pixel in the image.
    for i in range(1, len(xRange) - 1):
        if(xRange[i-1] < xIntersect  and xRange[i + 1] > xIntersect) :
            xIntersect = xRange[i];
            break;
    
    # Checking whether (xIntersect, yIntersect) is under shade
    imagePixelX = np.where(xRange == xIntersect);
    if(len(imagePixelX[0]) != 0):
        imagePixelX = imagePixelX[0][0];
    else:
        imagePixelX = -1;
        
    imagePixelY = np.where(yRange == yIntersect);
    if(len(imagePixelY[0]) != 0):
        imagePixelY = imagePixelY[0][0];
    else:
        imagePixelY = -1;
    
#     print(imagePixelX, imagePixelY)
    
    # Implies that point lies within the image
    if(imagePixelX != -1 and imagePixelY != -1):
        totalPixelCount += 1;
        # Checking if the point is also under shade
        if(totalMask2[imagePixelY, imagePixelX] == True):
            totalMask3[imagePixelY, imagePixelX] = False;
            shadedPixelCount += 1;
        
percentageCoverage = (shadedPixelCount / totalPixelCount) * 100

# %%
percentageCoverage
# Out:
# 73.43358395989975

# %%
plt.imshow(totalMask3)

# %%
shadedPixelCount
# Out:
# 293

# %%
totalPixelCount
# Out:
# 399

# %% [markdown]
# ## Iterating over all images to find shaded rate of all roads

# %%
# For each road, we store the total pixels in each image for that road.
# And out of those total pixels, how many are in shade.
totalRoadShadeCoverage = {};

# %%
for imageIndex in imageLinksDir:
    xIndex = imageIndex[0];
    yIndex = imageIndex[1];
    imgCoords = imgData['imageIndex'][f"{xIndex}_{yIndex}"];
    
    # Getting the corners for an image
    imgLatTop = imgCoords["lat"] + latFactor/2;
    imgLatBot = imgCoords["lat"] - latFactor/2;
    imgLongLeft = imgCoords["long"] - longFactor/2;
    imgLongRight = imgCoords["long"] + longFactor/2;
    
    # Converting image corners to Mercator Projection
    (xl, yt) = mp.latLngToPoint(imgLatTop, imgLongLeft);
    (xr, yb) = mp.latLngToPoint(imgLatBot, imgLongRight);
    
    # Sampling over the edges of the image, to kind of map the 400 pixels to coordinates
    yRange = np.linspace(yt, yb, 400);
    xRange = np.linspace(xl, xr, 400);
    
    roadsInImage = imageLinksDir[imageIndex];
    for road in roadsInImage:
        # Converting end-point coordinates of the road to Mercator projection
        nodePair0 = linkIDToNodePair[road]
        path0_node0 = nodeCoordDict[nodePair0[0]];
        path0_node1 = nodeCoordDict[nodePair0[1]];
        (x0, y0) = mp.latLngToPoint(path0_node0[0], path0_node0[1]);
        (x1, y1) = mp.latLngToPoint(path0_node1[0], path0_node1[1]);
        
        # All points below are Mercator's Projection.
        totalPixelCount = 0;
        shadedPixelCount = 0;
        for y in yRange:
            leftPoint = (xl, y);
            rightPoint = (xr, y);

            # Line parellel to top/bottom edge of the image.
            line1 = (leftPoint, rightPoint);

            # Line joining the endpoints of the pathway.
            # top and bottom no relevance to actual position.
            topPoint = (x0, y0);
            bottomPoint = (x1, y1);
            line2 = (topPoint, bottomPoint);

            # Calculating intersection point of the 2 lines.
            (xIntersect, yIntersect) = intersect.line_intersection(line1, line2);
            # If lines don't intersect
            if(math.isnan(xIntersect)):
                continue;

            # yIntersect should directly correspond to a pixel, as we mapped yRange to 400 pixels.
            # But it might not, as we our finding intersection using equation of line.
            for i in range(1, len(yRange) - 1):
                if(yRange[i-1] < yIntersect  and yRange[i + 1] > yIntersect) :
                    yIntersect = yRange[i];
                    break;
            # For xIntersect, we check between which two points in xRange does the xIntersect lies,
            # The point in between those 2 points will be our xIntersect pixel in the image.
            for i in range(1, len(xRange) - 1):
                if(xRange[i-1] < xIntersect  and xRange[i + 1] > xIntersect) :
                    xIntersect = xRange[i];
                    break;

            # Checking whether (xIntersect, yIntersect) is under shade
            imagePixelX = np.where(xRange == xIntersect);
            if(len(imagePixelX[0]) != 0):
                imagePixelX = imagePixelX[0][0];
            else:
                imagePixelX = -1;

            imagePixelY = np.where(yRange == yIntersect);
            if(len(imagePixelY[0]) != 0):
                imagePixelY = imagePixelY[0][0];
            else:
                imagePixelY = -1;

            # print(imagePixelX, imagePixelY)

            # Implies that point lies within the image
            if(imagePixelX != -1 and imagePixelY != -1):
                totalPixelCount += 1;
                # Checking if the point is also under shade
                if(totalMask2[imagePixelY, imagePixelX] == True):
                    totalMask3[imagePixelY, imagePixelX] = False;
                    shadedPixelCount += 1;
            
        if(not(totalRoadShadeCoverage.__contains__(road))):
            totalRoadShadeCoverage[road] = {
                "totalPixels": 0,
                "shadedPixels": 0,
                "percentageCover": 0
            }
        totalRoadShadeCoverage[road]["totalPixels"] += totalPixelCount;
        totalRoadShadeCoverage[road]["shadedPixels"] += shadedPixelCount;
        totalRoadShadeCoverage[road]["percentageCover"] = (totalRoadShadeCoverage[road]["shadedPixels"] / totalRoadShadeCoverage[road]["totalPixels"]) * 100;
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[147], line 46
#      43 line2 = (topPoint, bottomPoint);
#      45 # Calculating intersection point of the 2 lines.
# ---> 46 (xIntersect, yIntersect) = intersect.line_intersection(line1, line2);
#      47 # If lines don't intersect
#      48 if(math.isnan(xIntersect)):
#
# File ~/Desktop/ShadyProject/Shaded_planning/Utils/checkIntersection.py:81, in line_intersection(line1, line2)
#      79 div = det(xdiff, ydiff)
#      80 if div == 0:
# ---> 81     raise Exception('lines do not intersect')
#      83 d = (det(*line1), det(*line2))
#      84 x = det(d, xdiff) / div
#
# Exception: lines do not intersect

# %%
totalRoadShadeCoverage
# Out:
# {479: {'totalPixels': 1197,
#   'shadedPixels': 38,
#   'percentageCover': 3.1746031746031744},
#  480: {'totalPixels': 399,
#   'shadedPixels': 19,
#   'percentageCover': 4.761904761904762},
#  170: {'totalPixels': 799,
#   'shadedPixels': 13,
#   'percentageCover': 1.6270337922403004},
#  556: {'totalPixels': 799,
#   'shadedPixels': 29,
#   'percentageCover': 3.629536921151439},
#  281: {'totalPixels': 89,
#   'shadedPixels': 5,
#   'percentageCover': 5.617977528089887},
#  115: {'totalPixels': 493,
#   'shadedPixels': 3,
#   'percentageCover': 0.6085192697768762},
#  282: {'totalPixels': 1, 'shadedPixels': 0, 'percentageCover': 0.0},
#  295: {'totalPixels': 399,
#   'shadedPixels': 193,
#   'percentageCover': 48.370927318295735},
#  296: {'totalPixels': 399,
#   'shadedPixels': 193,
#   'percentageCover': 48.370927318295735},
#  297: {'totalPixels': 399,
#   'shadedPixels': 185,
#   'percentageCover': 46.365914786967416},
#  298: {'totalPixels': 399,
#   'shadedPixels': 185,
#   'percentageCover': 46.365914786967416},
#  635: {'totalPixels': 399,
#   'shadedPixels': 142,
#   'percentageCover': 35.58897243107769},
#  107: {'totalPixels': 254,
#   'shadedPixels': 5,
#   'percentageCover': 1.968503937007874},
#  505: {'totalPixels': 399, 'shadedPixels': 0, 'percentageCover': 0.0},
#  506: {'totalPixels': 399, 'shadedPixels': 0, 'percentageCover': 0.0},
#  558: {'totalPixels': 189,
#   'shadedPixels': 34,
#   'percentageCover': 17.989417989417987},
#  151: {'totalPixels': 400, 'shadedPixels': 4, 'percentageCover': 1.0},
#  329: {'totalPixels': 172,
#   'shadedPixels': 15,
#   'percentageCover': 8.720930232558139},
#  114: {'totalPixels': 322,
#   'shadedPixels': 69,
#   'percentageCover': 21.428571428571427},
#  272: {'totalPixels': 18, 'shadedPixels': 0, 'percentageCover': 0.0},
#  268: {'totalPixels': 399, 'shadedPixels': 0, 'percentageCover': 0.0},
#  269: {'totalPixels': 399, 'shadedPixels': 0, 'percentageCover': 0.0},
#  274: {'totalPixels': 12,
#   'shadedPixels': 4,
#   'percentageCover': 33.33333333333333},
#  108: {'totalPixels': 142, 'shadedPixels': 0, 'percentageCover': 0.0},
#  109: {'totalPixels': 131, 'shadedPixels': 0, 'percentageCover': 0.0},
#  548: {'totalPixels': 294,
#   'shadedPixels': 80,
#   'percentageCover': 27.2108843537415},
#  361: {'totalPixels': 104,
#   'shadedPixels': 6,
#   'percentageCover': 5.769230769230769},
#  736: {'totalPixels': 291,
#   'shadedPixels': 70,
#   'percentageCover': 24.054982817869416},
#  618: {'totalPixels': 45, 'shadedPixels': 18, 'percentageCover': 40.0},
#  650: {'totalPixels': 147,
#   'shadedPixels': 11,
#   'percentageCover': 7.482993197278912},
#  167: {'totalPixels': 798, 'shadedPixels': 0, 'percentageCover': 0.0},
#  601: {'totalPixels': 400, 'shadedPixels': 31, 'percentageCover': 7.75},
#  602: {'totalPixels': 798,
#   'shadedPixels': 55,
#   'percentageCover': 6.8922305764411025},
#  651: {'totalPixels': 252, 'shadedPixels': 0, 'percentageCover': 0.0},
#  284: {'totalPixels': 76,
#   'shadedPixels': 23,
#   'percentageCover': 30.263157894736842},
#  285: {'totalPixels': 13,
#   'shadedPixels': 5,
#   'percentageCover': 38.46153846153847},
#  515: {'totalPixels': 37, 'shadedPixels': 0, 'percentageCover': 0.0},
#  516: {'totalPixels': 37, 'shadedPixels': 0, 'percentageCover': 0.0},
#  517: {'totalPixels': 399,
#   'shadedPixels': 24,
#   'percentageCover': 6.015037593984962},
#  518: {'totalPixels': 399,
#   'shadedPixels': 24,
#   'percentageCover': 6.015037593984962},
#  286: {'totalPixels': 10, 'shadedPixels': 6, 'percentageCover': 60.0},
#  291: {'totalPixels': 400,
#   'shadedPixels': 14,
#   'percentageCover': 3.5000000000000004},
#  288: {'totalPixels': 400, 'shadedPixels': 140, 'percentageCover': 35.0},
#  337: {'totalPixels': 6,
#   'shadedPixels': 2,
#   'percentageCover': 33.33333333333333},
#  690: {'totalPixels': 400, 'shadedPixels': 0, 'percentageCover': 0.0},
#  743: {'totalPixels': 400, 'shadedPixels': 229, 'percentageCover': 57.25},
#  744: {'totalPixels': 400, 'shadedPixels': 229, 'percentageCover': 57.25},
#  338: {'totalPixels': 3,
#   'shadedPixels': 1,
#   'percentageCover': 33.33333333333333},
#  495: {'totalPixels': 400, 'shadedPixels': 12, 'percentageCover': 3.0},
#  496: {'totalPixels': 400, 'shadedPixels': 12, 'percentageCover': 3.0},
#  740: {'totalPixels': 400, 'shadedPixels': 12, 'percentageCover': 3.0},
#  741: {'totalPixels': 400, 'shadedPixels': 12, 'percentageCover': 3.0},
#  339: {'totalPixels': 4, 'shadedPixels': 1, 'percentageCover': 25.0},
#  603: {'totalPixels': 398,
#   'shadedPixels': 29,
#   'percentageCover': 7.2864321608040195},
#  653: {'totalPixels': 1, 'shadedPixels': 0, 'percentageCover': 0.0},
#  323: {'totalPixels': 398, 'shadedPixels': 0, 'percentageCover': 0.0},
#  326: {'totalPixels': 268,
#   'shadedPixels': 65,
#   'percentageCover': 24.253731343283583},
#  327: {'totalPixels': 96, 'shadedPixels': 75, 'percentageCover': 78.125},
#  328: {'totalPixels': 159,
#   'shadedPixels': 8,
#   'percentageCover': 5.031446540880504},
#  745: {'totalPixels': 4, 'shadedPixels': 1, 'percentageCover': 25.0},
#  320: {'totalPixels': 399,
#   'shadedPixels': 291,
#   'percentageCover': 72.93233082706767},
#  321: {'totalPixels': 399,
#   'shadedPixels': 291,
#   'percentageCover': 72.93233082706767},
#  746: {'totalPixels': 39,
#   'shadedPixels': 9,
#   'percentageCover': 23.076923076923077},
#  747: {'totalPixels': 39,
#   'shadedPixels': 9,
#   'percentageCover': 23.076923076923077}}
